# %% [markdown]
# # Exploring Machine Learning Datasets

# %% [markdown]
# This class we'll introduce you further to the idea of a dataset, exploring the ways in which they construct an image of the world for machine learning models. To do so, we'll use [FiftyOne](https://github.com/voxel51/fiftyone), an application that allows us to view datasets, their annotations, and a lot more.

# %%
# installing fiftyone
# !pip3 install fiftyone
# !pip3 install torch torchvision
# !!fiftyone plugins download https://github.com/voxel51/fiftyone-plugins
# Out:
# Requirement already satisfied: fiftyone in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (1.3.0)
# Requirement already satisfied: aiofiles in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (24.1.0)
# Requirement already satisfied: argcomplete in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (3.5.3)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (4.13.3)
# Requirement already satisfied: boto3 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (1.37.3)
# Requirement already satisfied: cachetools in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (5.5.2)
# Requirement already satisfied: dacite<1.8.0,>=1.6.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (1.7.0)
# Requirement already satisfied: Deprecated in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (1.2.18)
# Requirement already satisfied: ftfy in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (6.3.1)
# Requirement already satisfied: humanize in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (4.12.1)
# Requirement already satisfied: hypercorn>=0.13.2 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (0.17.3)
# Requirement already satisfied: Jinja2>=3 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (3.1.5)
# Requirement already satisfied: kaleido!=0.2.1.post1 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (0.2.1)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (3.10.1)
# Requirement already satisfied: mongoengine~=0.29.1 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (0.29.1)
# Requirement already satisfied: motor~=3.6.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (3.6.1)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (2.2.3)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (24.2)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (2.2.3)
# Requirement already satisfied: Pillow>=6.2 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (11.1.0)
# Requirement already satisfied: plotly>=4.14 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (6.0.0)
# Requirement already satisfied: pprintpp in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (0.4.0)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (5.9.0)
# Requirement already satisfied: pymongo~=4.9.2 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (4.9.2)
# Requirement already satisfied: pytz in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (2025.1)
# Requirement already satisfied: PyYAML in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (6.0.2)
# Requirement already satisfied: regex in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (2024.11.6)
# Requirement already satisfied: retrying in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (1.3.4)
# Requirement already satisfied: rtree in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (1.3.0)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (1.6.1)
# Requirement already satisfied: scikit-image in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (0.25.2)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (1.15.2)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (75.8.0)
# Requirement already satisfied: sseclient-py<2,>=1.7.2 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (1.8.0)
# Requirement already satisfied: sse-starlette<1,>=0.10.3 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (0.10.3)
# Requirement already satisfied: starlette>=0.24.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (0.46.0)
# Requirement already satisfied: strawberry-graphql in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (0.261.1)
# Requirement already satisfied: tabulate in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (0.9.0)
# Requirement already satisfied: xmltodict in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (0.14.2)
# Requirement already satisfied: universal-analytics-python3<2,>=1.0.1 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (1.1.1)
# Requirement already satisfied: pydash in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (8.0.5)
# Requirement already satisfied: fiftyone-brain<0.20,>=0.19.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (0.19.0)
# Requirement already satisfied: fiftyone-db<2.0,>=0.4 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (1.1.7)
# Requirement already satisfied: voxel51-eta<0.15,>=0.14.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (0.14.0)
# Requirement already satisfied: opencv-python-headless in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from fiftyone) (4.11.0.86)
# Requirement already satisfied: h11 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from hypercorn>=0.13.2->fiftyone) (0.14.0)
# Requirement already satisfied: h2>=3.1.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from hypercorn>=0.13.2->fiftyone) (4.2.0)
# Requirement already satisfied: priority in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from hypercorn>=0.13.2->fiftyone) (2.0.0)
# Requirement already satisfied: wsproto>=0.14.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from hypercorn>=0.13.2->fiftyone) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from Jinja2>=3->fiftyone) (3.0.2)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from plotly>=4.14->fiftyone) (1.28.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from pymongo~=4.9.2->fiftyone) (2.7.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from starlette>=0.24.0->fiftyone) (4.8.0)
# Requirement already satisfied: httpx>=0.10.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from universal-analytics-python3<2,>=1.0.1->fiftyone) (0.28.1)
# Requirement already satisfied: dill in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from voxel51-eta<0.15,>=0.14.0->fiftyone) (0.3.9)
# Requirement already satisfied: future in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from voxel51-eta<0.15,>=0.14.0->fiftyone) (1.0.0)
# Requirement already satisfied: glob2 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from voxel51-eta<0.15,>=0.14.0->fiftyone) (0.7)
# Requirement already satisfied: jsonlines in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from voxel51-eta<0.15,>=0.14.0->fiftyone) (4.0.0)
# Requirement already satisfied: py7zr in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from voxel51-eta<0.15,>=0.14.0->fiftyone) (0.22.0)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from voxel51-eta<0.15,>=0.14.0->fiftyone) (2.9.0.post0)
# Requirement already satisfied: rarfile in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from voxel51-eta<0.15,>=0.14.0->fiftyone) (4.2)
# Requirement already satisfied: requests in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from voxel51-eta<0.15,>=0.14.0->fiftyone) (2.32.3)
# Requirement already satisfied: six in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from voxel51-eta<0.15,>=0.14.0->fiftyone) (1.17.0)
# Requirement already satisfied: sortedcontainers in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from voxel51-eta<0.15,>=0.14.0->fiftyone) (2.4.0)
# Requirement already satisfied: tzlocal in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from voxel51-eta<0.15,>=0.14.0->fiftyone) (5.3)
# Requirement already satisfied: urllib3 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from voxel51-eta<0.15,>=0.14.0->fiftyone) (2.3.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from beautifulsoup4->fiftyone) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from beautifulsoup4->fiftyone) (4.12.2)
# Requirement already satisfied: botocore<1.38.0,>=1.37.3 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from boto3->fiftyone) (1.37.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from boto3->fiftyone) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from boto3->fiftyone) (0.11.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from Deprecated->fiftyone) (1.17.2)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from ftfy->fiftyone) (0.2.13)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from matplotlib->fiftyone) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from matplotlib->fiftyone) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from matplotlib->fiftyone) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from matplotlib->fiftyone) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from matplotlib->fiftyone) (3.2.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from pandas->fiftyone) (2025.1)
# Requirement already satisfied: networkx>=3.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from scikit-image->fiftyone) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from scikit-image->fiftyone) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from scikit-image->fiftyone) (2025.2.18)
# Requirement already satisfied: lazy-loader>=0.4 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from scikit-image->fiftyone) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from scikit-learn->fiftyone) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from scikit-learn->fiftyone) (3.5.0)
# Requirement already satisfied: graphql-core<3.4.0,>=3.2.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from strawberry-graphql->fiftyone) (3.2.6)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette>=0.24.0->fiftyone) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette>=0.24.0->fiftyone) (1.3.1)
# Requirement already satisfied: hyperframe<7,>=6.1 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from h2>=3.1.0->hypercorn>=0.13.2->fiftyone) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from h2>=3.1.0->hypercorn>=0.13.2->fiftyone) (4.1.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (1.0.7)
# Requirement already satisfied: attrs>=19.2.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from jsonlines->voxel51-eta<0.15,>=0.14.0->fiftyone) (25.1.0)
# Requirement already satisfied: texttable in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from py7zr->voxel51-eta<0.15,>=0.14.0->fiftyone) (1.7.0)
# Requirement already satisfied: pycryptodomex>=3.16.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from py7zr->voxel51-eta<0.15,>=0.14.0->fiftyone) (3.21.0)
# Requirement already satisfied: pyzstd>=0.15.9 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from py7zr->voxel51-eta<0.15,>=0.14.0->fiftyone) (0.16.2)
# Requirement already satisfied: pyppmd<1.2.0,>=1.1.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from py7zr->voxel51-eta<0.15,>=0.14.0->fiftyone) (1.1.1)
# Requirement already satisfied: pybcj<1.1.0,>=1.0.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from py7zr->voxel51-eta<0.15,>=0.14.0->fiftyone) (1.0.3)
# Requirement already satisfied: multivolumefile>=0.2.3 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from py7zr->voxel51-eta<0.15,>=0.14.0->fiftyone) (0.2.3)
# Requirement already satisfied: inflate64<1.1.0,>=1.0.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from py7zr->voxel51-eta<0.15,>=0.14.0->fiftyone) (1.0.1)
# Requirement already satisfied: brotli>=1.1.0 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from py7zr->voxel51-eta<0.15,>=0.14.0->fiftyone) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/dipcc/lib/python3.12/site-packages (from requests->voxel51-eta<0.15,>=0.14.0->fiftyone) (3.4.1)
# ['Downloading voxel51/fiftyone-plugins...',
#  '',
#  '',
#  '',
#  '  260.5Kb [10.7ms elapsed, ? remaining, 23.8Mb/s] ',
#  '                                                  ',
#  '',
#  '    3.6Mb [143.4ms elapsed, ? remaining, 24.8Mb/s] ',
#  '                                                   ',
#  '',
#  '   11.3Mb [246.3ms elapsed, ? remaining, 45.8Mb/s] ',
#  '                                                   ',
#  '',
#  '   16.6Mb [355.2ms elapsed, ? remaining, 46.7Mb/s] ',
#  '                                                   ',
#  '',
#  '   21.7Mb [459.7ms elapsed, ? remaining, 47.2Mb/s] ',
#  '                                                   ',
#  '',
#  '   26.6Mb [560.2ms elapsed, ? remaining, 47.4Mb/s] ',
#  '                                                   ',
#  '',
#  '   31.8Mb [666.6ms elapsed, ? remaining, 47.7Mb/s] ',
#  '                                                   ',
#  '',
#  '   36.7Mb [767.6ms elapsed, ? remaining, 47.8Mb/s] ',
#  '                                                   ',
#  '',
#  '   41.9Mb [874.8ms elapsed, ? remaining, 47.9Mb/s] ',
#  '                                                   ',
#  '',
#  '   47.2Mb [982.5ms elapsed, ? remaining, 48.3Mb/s] ',
#  '                                                   ',
#  '',
#  '   51.6Mb [1.1s elapsed, ? remaining, 50.1Mb/s]    ',
#  '                                                   ',
#  '',
#  '   57.8Mb [1.2s elapsed, ? remaining, 48.6Mb/s]    ',
#  '                                                   ',
#  '',
#  '   63.0Mb [1.3s elapsed, ? remaining, 48.8Mb/s]    ',
#  '                                                   ',
#  '',
#  '   67.7Mb [1.4s elapsed, ? remaining, 48.5Mb/s]    ',
#  '                                                   ',
#  '',
#  '   72.4Mb [1.5s elapsed, ? remaining, 48.4Mb/s]    ',
#  '                                                   ',
#  '',
#  '   77.6Mb [1.6s elapsed, ? remaining, 48.5Mb/s]    ',
#  '                                                   ',
#  '',
#  '   82.6Mb [1.7s elapsed, ? remaining, 48.5Mb/s]    ',
#  '                                                   ',
#  '',
#  '   87.6Mb [1.8s elapsed, ? remaining, 48.5Mb/s]    ',
#  '                                                   ',
#  '',
#  '   92.3Mb [1.9s elapsed, ? remaining, 48.3Mb/s]    ',
#  '                                                   ',
#  '',
#  '   97.3Mb [2.0s elapsed, ? remaining, 49.9Mb/s]    ',
#  '                                                   ',
#  '',
#  '  102.4Mb [2.1s elapsed, ? remaining, 48.5Mb/s]    ',
#  '                                                   ',
#  '',
#  '  107.4Mb [2.2s elapsed, ? remaining, 48.4Mb/s]    ',
#  '                                                   ',
#  '',
#  '  111.8Mb [2.3s elapsed, ? remaining, 48.0Mb/s]    ',
#  '                                                   ',
#  '',
#  '  117.5Mb [2.4s elapsed, ? remaining, 48.9Mb/s]    ',
#  '                                                   ',
#  '',
#  '  122.8Mb [2.5s elapsed, ? remaining, 48.8Mb/s]    ',
#  '                                                   ',
#  '',
#  '  127.9Mb [2.6s elapsed, ? remaining, 48.9Mb/s]    ',
#  '                                                   ',
#  '',
#  '  133.0Mb [2.7s elapsed, ? remaining, 48.9Mb/s]    ',
#  '                                                   ',
#  '',
#  '  138.2Mb [2.9s elapsed, ? remaining, 49.2Mb/s]    ',
#  '                                                   ',
#  '',
#  '  143.6Mb [3.0s elapsed, ? remaining, 49.2Mb/s]    ',
#  '                                                   ',
#  '',
#  '  149.0Mb [3.1s elapsed, ? remaining, 49.3Mb/s]    ',
#  '                                                   ',
#  '',
#  '  154.3Mb [3.2s elapsed, ? remaining, 49.4Mb/s]    ',
#  '                                                   ',
#  '',
#  '  159.3Mb [3.3s elapsed, ? remaining, 50.0Mb/s]    ',
#  '                                                   ',
#  '',
#  '  164.2Mb [3.4s elapsed, ? remaining, 49.3Mb/s]    ',
#  '                                                   ',
#  '',
#  '  169.8Mb [3.5s elapsed, ? remaining, 49.5Mb/s]    ',
#  '                                                   ',
#  '',
#  '  174.6Mb [3.6s elapsed, ? remaining, 49.3Mb/s]    ',
#  '                                                   ',
#  '',
#  '  179.8Mb [3.7s elapsed, ? remaining, 49.6Mb/s]    ',
#  '                                                   ',
#  '',
#  '  185.1Mb [3.8s elapsed, ? remaining, 49.5Mb/s]    ',
#  '                                                   ',
#  '',
#  '  190.3Mb [3.9s elapsed, ? remaining, 49.7Mb/s]    ',
#  '                                                   ',
#  '',
#  '  194.5Mb [4.0s elapsed, ? remaining, 46.4Mb/s]    ',
#  '                                                   ',
#  '',
#  '  199.2Mb [4.3s elapsed, ? remaining, 39.2Mb/s]    ',
#  '                                                   ',
#  '',
#  '  200.7Mb [4.5s elapsed, ? remaining, 35.1Mb/s]    ',
#  '                                                   ',
#  '',
#  '  201.2Mb [4.6s elapsed, ? remaining, 29.3Mb/s]    ',
#  '                                                   ',
#  '',
#  '  201.8Mb [4.8s elapsed, ? remaining, 24.2Mb/s]    ',
#  '                                                   ',
#  '',
#  '  207.0Mb [4.9s elapsed, ? remaining, 24.4Mb/s]    ',
#  '                                                   ',
#  '',
#  '  212.2Mb [5.0s elapsed, ? remaining, 24.2Mb/s]    ',
#  '                                                   ',
#  '',
#  '  217.5Mb [5.1s elapsed, ? remaining, 24.3Mb/s]    ',
#  '                                                   ',
#  '',
#  '  222.2Mb [5.2s elapsed, ? remaining, 23.9Mb/s]    ',
#  '                                                   ',
#  '',
#  '  227.4Mb [5.3s elapsed, ? remaining, 25.4Mb/s]    ',
#  '                                                   ',
#  '',
#  '  232.6Mb [5.5s elapsed, ? remaining, 29.3Mb/s]    ',
#  '                                                   ',
#  '',
#  '  238.4Mb [5.6s elapsed, ? remaining, 34.0Mb/s]    ',
#  '                                                   ',
#  '',
#  '  243.6Mb [5.7s elapsed, ? remaining, 41.1Mb/s]    ',
#  '                                                   ',
#  '',
#  '  248.9Mb [5.8s elapsed, ? remaining, 48.9Mb/s]    ',
#  '                                                   ',
#  '',
#  '  254.0Mb [5.9s elapsed, ? remaining, 48.9Mb/s]    ',
#  '                                                   ',
#  '',
#  '  259.3Mb [6.0s elapsed, ? remaining, 48.7Mb/s]    ',
#  '                                                   ',
#  '',
#  '  264.5Mb [6.1s elapsed, ? remaining, 49.0Mb/s]    ',
#  '                                                   ',
#  '',
#  '  269.3Mb [6.2s elapsed, ? remaining, 48.5Mb/s]    ',
#  '                                                   ',
#  '',
#  '  275.5Mb [6.3s elapsed, ? remaining, 49.5Mb/s]    ',
#  '                                                   ',
#  '',
#  '  280.8Mb [6.4s elapsed, ? remaining, 50.1Mb/s]    ',
#  '                                                   ',
#  '',
#  '  285.9Mb [6.5s elapsed, ? remaining, 49.4Mb/s]    ',
#  '                                                   ',
#  '',
#  '  291.1Mb [6.6s elapsed, ? remaining, 49.5Mb/s]    ',
#  '                                                   ',
#  '',
#  '  296.4Mb [6.7s elapsed, ? remaining, 49.2Mb/s]    ',
#  '                                                   ',
#  '',
#  '  301.6Mb [6.8s elapsed, ? remaining, 49.2Mb/s]    ',
#  '                                                   ',
#  '',
#  '  306.4Mb [7.0s elapsed, ? remaining, 49.0Mb/s]    ',
#  '                                                   ',
#  '',
#  '  311.6Mb [7.1s elapsed, ? remaining, 48.9Mb/s]    ',
#  '                                                   ',
#  '',
#  '  316.8Mb [7.2s elapsed, ? remaining, 49.9Mb/s]    ',
#  '                                                   ',
#  '',
#  '  319.3Mb [7.3s elapsed, ? remaining, 46.4Mb/s]    ',
#  '                                                   ',
#  '',
#  '  324.6Mb [7.4s elapsed, ? remaining, 46.1Mb/s]    ',
#  '                                                   ',
#  '',
#  '  329.3Mb [7.5s elapsed, ? remaining, 46.1Mb/s]    ',
#  "Skipping existing plugin '@voxel51/operator-examples'",
#  "Skipping existing plugin '@voxel51/plugins'",
#  "Skipping existing plugin '@voxel51/delegated'",
#  "Skipping existing plugin '@voxel51/io'",
#  "Skipping existing plugin '@voxel51/label_count'",
#  "Skipping existing plugin '@voxel51/annotation'",
#  "Skipping existing plugin '@voxel51/utils'",
#  "Skipping existing plugin '@voxel51/hello-world'",
#  "Skipping existing plugin '@voxel51/dashboard'",
#  "Skipping existing plugin '@voxel51/zoo'",
#  "Skipping existing plugin '@voxel51/evaluation'",
#  "Skipping existing plugin '@voxel51/brain'",
#  "Skipping existing plugin '@voxel51/metric-examples'",
#  "Skipping existing plugin '@voxel51/panel-examples'",
#  "Skipping existing plugin '@voxel51/runs'",
#  "Skipping existing plugin '@voxel51/indexes'"]

# %%
# here we import fiftyone and fiftyone zoo, a quick way to access ML datasets via fiftyone.
import fiftyone as fo
import fiftyone.zoo as foz

# %%
# this function allows us to list all the datasets available in fiftyone zoo
foz.list_zoo_datasets()
# Out:
# ['activitynet-100',
#  'activitynet-200',
#  'bdd100k',
#  'caltech101',
#  'caltech256',
#  'cifar10',
#  'cifar100',
#  'cityscapes',
#  'coco-2014',
#  'coco-2017',
#  'fashion-mnist',
#  'fiw',
#  'hmdb51',
#  'imagenet-2012',
#  'imagenet-sample',
#  'kinetics-400',
#  'kinetics-600',
#  'kinetics-700',
#  'kinetics-700-2020',
#  'kitti',
#  'kitti-multiview',
#  'lfw',
#  'mnist',
#  'open-images-v6',
#  'open-images-v7',
#  'places',
#  'quickstart',
#  'quickstart-3d',
#  'quickstart-geo',
#  'quickstart-groups',
#  'quickstart-video',
#  'sama-coco',
#  'ucf101',
#  'voc-2007',
#  'voc-2012']

# %%
# this function lists all currently downloaded datasets
foz.list_downloaded_zoo_datasets()
# Out:
# {'coco-2017': ('/Users/muradkhan/fiftyone/coco-2017',
#   <fiftyone.zoo.datasets.ZooDatasetInfo at 0x11905bfe0>),
#  'quickstart-video': ('/Users/muradkhan/fiftyone/quickstart-video',
#   <fiftyone.zoo.datasets.ZooDatasetInfo at 0x108203f50>),
#  'quickstart-groups': ('/Users/muradkhan/fiftyone/quickstart-groups',
#   <fiftyone.zoo.datasets.ZooDatasetInfo at 0x119eef980>),
#  'imagenet-sample': ('/Users/muradkhan/fiftyone/imagenet-sample',
#   <fiftyone.zoo.datasets.ZooDatasetInfo at 0x11a5c3ad0>),
#  'quickstart': ('/Users/muradkhan/fiftyone/quickstart',
#   <fiftyone.zoo.datasets.ZooDatasetInfo at 0x11a5c3b00>),
#  'quickstart-3d': ('/Users/muradkhan/fiftyone/quickstart-3d',
#   <fiftyone.zoo.datasets.ZooDatasetInfo at 0x11a5e3590>)}

# %%
# this function loads a specific dataset from fiftyone zoo. We can load any dataset by passing the name of the dataset as a string.
foz.load_zoo_dataset("quickstart")
# foz.list_zoo_datasets("detection")
# Out:
# Dataset already downloaded
# Loading existing dataset 'quickstart'. To reload from disk, either delete the existing dataset or provide a custom `dataset_name` to use
# Name:        quickstart
# Media type:  image
# Num samples: 200
# Persistent:  True
# Tags:        []
# Sample fields:
#     id:               fiftyone.core.fields.ObjectIdField
#     filepath:         fiftyone.core.fields.StringField
#     tags:             fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:         fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     created_at:       fiftyone.core.fields.DateTimeField
#     last_modified_at: fiftyone.core.fields.DateTimeField
#     ground_truth:     fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     uniqueness:       fiftyone.core.fields.FloatField
#     predictions:      fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)

# %% [markdown]
# # Explore the App

# %%
#select your initial dataset
dataset = foz.load_zoo_dataset("quickstart")
# Out:
# Dataset already downloaded
# Loading existing dataset 'quickstart-groups'. To reload from disk, either delete the existing dataset or provide a custom `dataset_name` to use

# %%
#launch a local session of the fiftyone app
session = fo.launch_app(dataset, auto=False)
# Out:
# Session launched. Run `session.show()` to open the App in a cell output.

# %%
session.show
# Out:
# <bound method Session.show of Dataset:         quickstart-groups
# Media type:      group
# Num groups:      200
# Selected groups: 0
# Selected labels: 0
# Session URL:     http://localhost:5151/>
